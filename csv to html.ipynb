# %%
import pandas as pd

# %%
cities_path = "Resources/WeatherPy.csv"

# %%
cities_df = pd.read_csv(cities_path)
cities_df.dropna()
cities_df['Date'] =  cities_df[["Date"]].apply(pd.to_datetime)
cities_df
# Out:
#      Unnamed: 0              City      Lat       Lng  Max Temp  Humidity  \
# 0             0   arraial do cabo -22.9661  -42.0278     21.92      64.0
# 1             1           vaitupu -21.2000 -175.2000     26.00      94.0
# 2             2             vaini  18.2164   42.5053     19.00      42.0
# 3             3              abha -33.5906   26.8910     14.32      81.0
# 4             4  illoqqortoormiut  19.7297 -155.0900     26.00      65.0
# ..          ...               ...      ...       ...       ...       ...
# 614         614              hofn      NaN       NaN       NaN       NaN
# 615         615           cam pha      NaN       NaN       NaN       NaN
# 616         616            bacuit      NaN       NaN       NaN       NaN
# 617         617      torbat-e jam      NaN       NaN       NaN       NaN
# 618         618   port hawkesbury      NaN       NaN       NaN       NaN
#
#      Cloudiness  Wind Speed Country                          Date
# ...

# %%
del cities_df['Unnamed: 0']

# %%
cities=cities_df.dropna()

# %%
html = cities.to_html()

# %%
text_file = open("Resources\data2.html", "w")
text_file.write(html)
text_file.close()
